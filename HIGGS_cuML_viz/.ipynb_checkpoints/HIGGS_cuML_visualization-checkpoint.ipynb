# %% [markdown]
# # GPU Acceleration
#
# The below example demonstrates the significant performance boost achieved through GPU acceleration.
#
#
# Three tools are utilized to produce the below visualizations:
# 1. cuDF Pandas DataFrame (GPU) for data operations on dataset size of 1M
# 2. cuML K-Means and UMAP (GPU) for clustering and dimensionality reduction for 2D & 3D visualizations
#
# The HIGGS dataset can be downloaded from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/static/public/280/higgs.zip).

# %%
#download the HIGGS dataset
# !wget https://archive.ics.uci.edu/static/public/280/higgs.zip
# !unzip -p higgs.zip HIGGS.csv.gz | gunzip > HIGGS.csv
# Out:
# --2025-08-17 21:58:13--  https://archive.ics.uci.edu/static/public/280/higgs.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# connected. to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443...
# 200 OKequest sent, awaiting response...
# Length: unspecified
# Saving to: ‘higgs.zip’
#
# higgs.zip               [                 <=>]   2.62G  31.6MB/s    in 81s
#
# 2025-08-17 21:59:34 (33.3 MB/s) - ‘higgs.zip’ saved [2816865137]

# %%
#run the python script using GPU-accelerated pandas dataframe and scikit-learn
# !python -m cudf.pandas -m cuml.accel app_ml.py
# Out:
# [2025-08-17 22:01:15.461] [CUML] [info] Building knn graph using nn descent (configured from build_algo='auto')
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app 'app_ml'
#  * Debug mode: on
# [2025-08-17 22:01:45.796] [CUML] [info] Building knn graph using nn descent (configured from build_algo='auto')
# ^C
