# %% [markdown]
# # GPU Acceleration
#
# Plotly Dash can integrate with cuxfilter and Datashader to create interactive visualizations. The below example demonstrates the significant performance boost achieved through GPU acceleration.

# %% [markdown]
# Three tools are utilized to produce the below visualizations:
# 1. cuDF Pandas DataFrame (GPU) for data operations to extrapolate the dataset size to 1M
# 2. Datashader for large-scale visualization (GPU rasterization)

# %%
# !python -m cudf.pandas app_8_gpu_datashader.py
# Out:
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app 'app_8_gpu_datashader'
#  * Debug mode: on
